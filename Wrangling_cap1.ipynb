# %% [markdown]
# Capstone 1 Wrangling
#
# All companies that participate in wholesale energy markets are required to submit a quarterly report detailing each transaction to the Federal Energy Regulatory Commission (FERC). This information is then made publicly available for download on FERC’s website at https://eqrreportviewer.ferc.gov/.
#
# I've dowloaded all of the hourly data for Florida as a csv file and saved it to my desktop. My first step is to load the file as a dataframe.

# %%
import pandas as pd
data = pd.read_csv(r'C:\Users\anhem44\Desktop\Capstone1\all_data_cap1.csv')
data.head()
# Out:
#        DATE        SELLER_COMPANY                          SELLER_COMPANY_OLD  \
# 0  1/1/2014                EXELON              EXELON GENERATION COMPANY, LLC
# 1  1/1/2014      SOUTHERN COMPANY  SOUTHERN COMPANY SERVICES, INC. (AS AGENT)
# 2  1/1/2014  THE ENERGY AUTHORITY                  THE ENERGY AUTHORITY, INC.
# 3  1/1/2014  THE ENERGY AUTHORITY                  THE ENERGY AUTHORITY, INC.
# 4  1/1/2014  THE ENERGY AUTHORITY                  THE ENERGY AUTHORITY, INC.
#
#                   C_BUYER_NAME                       C_BUYER_NAME_OLD  \
# 0         THE ENERGY AUTHORITY                   THE ENERGY AUTHORITY
# 1       SEMINOLE ELECTRIC COOP    SEMINOLE ELECTRIC COOPERATIVE, INC.
# 2  J.P. MORGAN CHASE & COMPANY  JP MORGAN VENTURES ENERGY CORPORATION
# 3                       EXELON         EXELON GENERATION COMPANY, LLC
# 4                       EXELON         EXELON GENERATION COMPANY, LLC
#
#     Region  Contract_Service_Agreement_id  TR_CONTRACT_ID  loc  \
# 0  Florida                          12870          717562  FPL
# 1  Florida                            481         1888312  FPL
# 2  Florida                          30760          892022  FPL
# 3  Florida                          30789          892011  FPL
# 4  Florida                          30789          892011  FPL
#
#          TR_TIMEZONE    ...    index_loc_seller  index_loc_oldseller  \
# 0  EASTERNPREVAILING    ...           30.000000            30.000000
# 1    CENTRALSTANDARD    ...           38.000000            38.000000
# 2  EASTERNPREVAILING    ...           31.750000            31.750000
# 3  EASTERNPREVAILING    ...           31.500000            31.500000
# 4  EASTERNPREVAILING    ...           31.451613            31.451613
#
#   transcharge price_minus_index  price_above_trans  price_above_trans_mwh  \
# 0           8         -1.471054                  0                    0.0
# 1           8          2.114532                  0                    0.0
# 2           8          0.893512                  0                    0.0
# 3           8          1.272839                  0                    0.0
# 4           8          1.407159                  0                    0.0
#
#    transaction_len  year  qtr  benchhub
# 0           Hourly  2014    1       FPL
# 1           Hourly  2014    1       FPL
# 2           Hourly  2014    1       FPL
# 3           Hourly  2014    1       FPL
# 4           Hourly  2014    1       FPL
#
# [5 rows x 31 columns]

# %% [markdown]
# With the data loaded I double check the datatypoes to isnure that there were no errors in the upload.

# %%
data.dtypes
# Out:
# DATE                              object
# SELLER_COMPANY                    object
# SELLER_COMPANY_OLD                object
# C_BUYER_NAME                      object
# C_BUYER_NAME_OLD                  object
# Region                            object
# Contract_Service_Agreement_id      int64
# TR_CONTRACT_ID                     int64
# loc                               object
# TR_TIMEZONE                       object
# TR_CLASS_NAME                     object
# PRICEINDOLPERMWH                 float64
# TR_DELV_SPEC_LOC                  object
# TRADE_DATE                        object
# HOUROFDAY                          int64
# QUANTITYINMWH                    float64
# HOURLYTRANSCHARGE                float64
# HOUR_FREQ                          int64
# weighted_pricemw                 float64
# index_loc                        float64
# index_bench                      float64
# index_loc_seller                 float64
# index_loc_oldseller              float64
# transcharge                        int64
# price_minus_index                float64
# price_above_trans                  int64
# price_above_trans_mwh            float64
# transaction_len                   object
# year                               int64
# qtr                                int64
# benchhub                          object
# dtype: object

# %% [markdown]
# Everythingg looks good, with the exception of the 'TRADE_DATE' column. This column contains the date and hour that the trade occured and should be a date time, but during upload it was classified as an object. So my next step is to convert it to a data time and check the results.

# %%
data['TRADE_DATE'] = pd.to_datetime(data['TRADE_DATE'])      
data['TRADE_DATE'].head()
# Out:
# 0   2014-01-01 22:00:00
# 1   2014-01-01 18:00:00
# 2   2014-01-01 02:00:00
# 3   2014-01-01 03:00:00
# 4   2014-01-01 04:00:00
# Name: TRADE_DATE, dtype: datetime64[ns]

# %% [markdown]
# Finally, since the goal of this project was to predict prices for a FERC specific time period and season I used the following to create these variables in the data frame.

# %%
data['FERC_time'] = 'off_peak'
data['FERC_time'][(data['TRADE_DATE'].dt.weekday <= 5) & (data['TRADE_DATE'].dt.hour >= 6) & (data['TRADE_DATE'].dt.hour <= 21)]='peak' 

data['FERC_season'] = 'shoulder'
data['FERC_season'][(data['TRADE_DATE'].dt.month <= 2) | (data['TRADE_DATE'].dt.month >= 12)]='winter' 
data['FERC_season'][(data['TRADE_DATE'].dt.month <= 8) & (data['TRADE_DATE'].dt.month >= 6)]= 'summer'
data.head()
# Out:
# C:\Users\anhem44\AppData\Local\Continuum\Anaconda3\lib\site-packages\ipykernel\__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# C:\Users\anhem44\AppData\Local\Continuum\Anaconda3\lib\site-packages\ipykernel\__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\anhem44\AppData\Local\Continuum\Anaconda3\lib\site-packages\ipykernel\__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#        DATE        SELLER_COMPANY                          SELLER_COMPANY_OLD  \
# 0  1/1/2014                EXELON              EXELON GENERATION COMPANY, LLC
# 1  1/1/2014      SOUTHERN COMPANY  SOUTHERN COMPANY SERVICES, INC. (AS AGENT)
# 2  1/1/2014  THE ENERGY AUTHORITY                  THE ENERGY AUTHORITY, INC.
# 3  1/1/2014  THE ENERGY AUTHORITY                  THE ENERGY AUTHORITY, INC.
# 4  1/1/2014  THE ENERGY AUTHORITY                  THE ENERGY AUTHORITY, INC.
#
#                   C_BUYER_NAME                       C_BUYER_NAME_OLD  \
# 0         THE ENERGY AUTHORITY                   THE ENERGY AUTHORITY
# 1       SEMINOLE ELECTRIC COOP    SEMINOLE ELECTRIC COOPERATIVE, INC.
# 2  J.P. MORGAN CHASE & COMPANY  JP MORGAN VENTURES ENERGY CORPORATION
# 3                       EXELON         EXELON GENERATION COMPANY, LLC
# 4                       EXELON         EXELON GENERATION COMPANY, LLC
#
#     Region  Contract_Service_Agreement_id  TR_CONTRACT_ID  loc  \
# 0  Florida                          12870          717562  FPL
# 1  Florida                            481         1888312  FPL
# 2  Florida                          30760          892022  FPL
# 3  Florida                          30789          892011  FPL
# 4  Florida                          30789          892011  FPL
#
#          TR_TIMEZONE     ...      transcharge  price_minus_index  \
# 0  EASTERNPREVAILING     ...                8          -1.471054
# 1    CENTRALSTANDARD     ...                8           2.114532
# 2  EASTERNPREVAILING     ...                8           0.893512
# 3  EASTERNPREVAILING     ...                8           1.272839
# 4  EASTERNPREVAILING     ...                8           1.407159
#
#   price_above_trans price_above_trans_mwh  transaction_len  year  qtr  \
# 0                 0                   0.0           Hourly  2014    1
# 1                 0                   0.0           Hourly  2014    1
# 2                 0                   0.0           Hourly  2014    1
# 3                 0                   0.0           Hourly  2014    1
# 4                 0                   0.0           Hourly  2014    1
#
#    benchhub  FERC_time  FERC_season
# 0       FPL   off_peak       winter
# 1       FPL       peak       winter
# 2       FPL   off_peak       winter
# 3       FPL   off_peak       winter
# 4       FPL   off_peak       winter
#
# [5 rows x 33 columns]

# %% [markdown]
# Since I will require two data sets for this project, one for training my modlea and one for testing my model I split the data frame into two.
#
# For simplicities sake, I've exported this data frame to a csv so that I don't have to clean the data every time.

# %%
cap1_training = data['TRADE_DATE'].dt.year <= 2015
cap1_training_data = data[cap1_training]

cap1_testing = data['TRADE_DATE'].dt.year == 2016
cap1_testing_data = data[cap1_testing]

cap1_testing_data.to_csv(r"C:\Users\anhem44\Data\cap1_testing_data.csv")
cap1_training_data.to_csv(r"C:\Users\anhem44\Data\cap1_training_data.csv")

# %%
len(cap1_testing_data)
# Out:
# 16622

# %%
len(cap1_training_data)
# Out:
# 62495

# %% [markdown]
# I am left with two csv files containing 62k rows for training and 16k for testing.
